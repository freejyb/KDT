# %% [markdown]
# -「금융분석 AI Agent」
# - 이 과정의 핵심은 Agent 기술 자체보다 금융분석 업무를 Agent로 구현하는 능력에 두겠습니다.
# - 매 차시 만든 결과물이 마지막에 하나의 AI Equity Research Agent로 합쳐지는 프로젝트형 구조입니다.

# %%
# 기업 분석 요청
#      ↓
# Planning Agent
#      ↓
# ┌────────────────────────────┐
# │ 데이터 수집                │
# │ · 주가 / 시장 데이터       │
# │ · 재무제표                 │
# │ · 공시 / 뉴스              │
# └────────────────────────────┘
#      ↓
# ┌────────────────────────────┐
# │ 금융분석 Tools             │
# │ · 수익률 / 변동성          │
# │ · 재무비율                 │
# │ · 성장성                   │
# │ · Valuation                │
# └────────────────────────────┘
#      ↓
# Financial Analyst Agent
#      ↓
# Risk / Critic Agent
#      ↓
# AI Equity Research Report

# %% [markdown]
# # 1회차 — 금융분석 업무를 AI Agent로 바꾸기

# %% [markdown]
# - 목표: 생성형 AI와 Agent의 차이를 이해하고 금융 애널리스트 업무를 Agent Workflow로 분해합니다.
# - LLM → RAG → Tool Calling → Agent → Multi-Agent의 발전 관계를 설명합니다.

# %%
# 기업 이해
#  ↓
# 재무제표 확인
#  ↓
# 재무비율 계산
#  ↓
# 주가 분석
#  ↓
# Valuation
#  ↓
# 뉴스/산업 조사
#  ↓
# Risk 분석
#  ↓
# 투자 의견

# %% [markdown]
# - 이것을 Agent 구조로 바꿉니다.

# %%
# Goal
#  ↓
# Planning
#  ↓
# Tool Selection
#  ↓
# Tool Execution
#  ↓
# Observation
#  ↓
# Reasoning
#  ↓
# Final Answer

# %% [markdown]
# # 2회차 — 금융 데이터 분석 Tool 만들기

# %% [markdown]
# - 2차시 목표: Agent가 사용할 주가 분석 Tool을 Python으로 구현합니다. -->  analyze_stock() 함수 완성
# - 금융 개념은 수익률, 누적수익률, 변동성, 최대낙폭(MDD), 이동평균 정도로 제한합니다.

# %%
# 1. 라이브러리 설치

# %%
# !pip install yfinance pandas numpy matplotlib

# %%
# 2. 라이브러리 불러오기
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1) 주가 데이터 수집 함수
# yfinance를 이용해 삼성전자의 최근 1년 주가 데이터를 가져온 뒤, 데이터의 크기와 앞부분을 확인하는 코드
# "005930.KS"	삼성전자 종목코드, KS	한국거래소(KOSPI) 종목이라는 의미
# period="1y"	최근 1년 데이터
# auto_adjust=True	배당·주식분할 등을 반영한 수정주가 기준으로 조정
# progress=False	다운로드 진행 표시를 화면에 출력하지 않음

# %%
stock = yf.download(
    "005930.KS",
    period="1y",
    auto_adjust=True,
    progress=False
)

print(stock.shape)
stock.head()
# Out:
# (243, 5)
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2025-09-17  77230.820312  78119.666071  76144.453275  78119.666071  20856317
# 2025-09-18  79304.804688  79502.325994  77625.873580  78119.676847  25619035
# 2025-09-22  82465.140625  82958.943862  80094.885086  80489.927676  27529656
# 2025-09-23  83650.265625  84835.393355  82563.898539  84736.632711  23610263
# 2025-09-24  84341.593750  84440.354398  82662.662727  83156.465969  18300997

# %%
# 데이터가 비어 있는지 검사
# def get_stock_price : 함수 정의
# if df.empty:
# df.empty는 데이터프레임이 비어 있는지를 확인합니다.
# 주가를 정상적으로 받았다면:df.empty → False
# 주가를 하나도 받지 못했다면:df.empty → True

# %%
def get_stock_price(
    ticker,
    start="2025-01-01"
):
    df = yf.download(
        ticker,
        start=start,
        auto_adjust=True,
        progress=False
    )

    if df.empty:
        raise ValueError(
            f"{ticker}의 주가 데이터를 가져오지 못했습니다. "
            "인터넷 연결, ticker, yfinance 버전을 확인하세요."
        )

    return df

# %%
stock = get_stock_price("005930.KS")

stock.head()
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2025-01-02  52107.089844  52302.247484  51033.722824  51424.038104  16630538
# 2025-01-03  53082.882812  53765.934613  51521.621553  51521.621553  19318046
# 2025-01-06  54546.562500  54839.298971  52985.301319  53082.880143  19034284
# 2025-01-07  54058.675781  55912.673687  54058.675781  55424.779501  17030235
# 2025-01-08  55912.667969  56107.825623  53375.618462  53473.197289  26593553

# %%
# 2) 수익률 계산 함수

# %%
def calculate_return(df):
    result = df.copy()
    
    result["Return"] = (
        result["Close"]
        .pct_change()
    )
    
    return result

# %%
stock = calculate_return(stock)

stock[["Close", "Return"]].head()
# Out:
# Price              Close    Return
# Ticker         005930.KS
# Date
# 2025-01-02  52107.089844       NaN
# 2025-01-03  53082.882812  0.018727
# 2025-01-06  54546.562500  0.027573
# 2025-01-07  54058.675781 -0.008944
# 2025-01-08  55912.667969  0.034296

# %%
# 3) 변동성 계산 함수
# 주가의 일별 수익률을 계산한 후, 그 수익률의 표준편차를 연환산하여 연간 변동성(Annualized Volatility)을 계산
# df라는 주가 데이터프레임을 입력받아 변동성을 계산하는 함수를 정의
# .dropna() :  NaN을 제거합니다.
# 주식시장의 1년 거래일을 약 252일로 보고,연환산합니다.

# %%
def calculate_volatility(df):
    
    returns = (
        df["Close"]
        .pct_change()
        .dropna()
    )
    
    volatility = (
        returns.std()
        * np.sqrt(252)
    )
    
    return float(
        volatility.iloc[0]
    )

# %%
volatility = calculate_volatility(stock)

print(
    "Annualized Volatility:",
    volatility
)
# Out:
# Annualized Volatility: 0.6141655629359764

# %%
# 4) MDD 계산 함수
# 주가가 고점에서 가장 크게 하락한 비율인 MDD(Maximum Drawdown, 최대낙폭)를 계산
# cumprod()는 누적해서 곱한다는 의미
# cummax()는 그 시점까지의 최고값을 계속 기록합니다.
# Drawdown은 현재 자산이 이전 최고점에서 얼마나 하락했는가를 계산합니다.
# mdd = drawdown.min() Drawdown 중에서 가장 작은 값, 즉 가장 크게 떨어졌던 순간을 찾습니다.
# float(...) : 일반적인 숫자로 변환합니다.

# %%
def calculate_mdd(df):
    
    close = df["Close"]
    
    returns = (
        close
        .pct_change()
        .dropna()
    )
    
    wealth = (
        1 + returns
    ).cumprod()
    
    peak = wealth.cummax()
    
    drawdown = (
        wealth / peak
        - 1
    )
    
    mdd = drawdown.min()
    
    return float(
        mdd.iloc[0]
    )

# %%
mdd = calculate_mdd(stock)

print(
    "Maximum Drawdown:",
    mdd
)
# Out:
# Maximum Drawdown: -0.42833575022000536

# %%
# 5) 누적수익률 함수
# 주가의 일별 수익률을 구한 다음, 이를 복리 방식으로 누적하여 기간별 누적수익률(Cumulative Return)을 계산하는 함수
# 1 + returns를 하는 이유:1 + returns, 수익률을 수익배수로 바꾸는 과정입니다.--> 복리 계산
# cumprod()는 cumulative product, 즉 앞에서부터 계속 곱한다는 뜻입니다.

# %%
def calculate_cumulative_return(df):
    
    close = df["Close"]
    
    returns = (
        close
        .pct_change()
        .dropna()
    )
    
    cumulative_return = (
        1 + returns
    ).cumprod() - 1
    
    return cumulative_return

# %%
cumulative_return = (
    calculate_cumulative_return(stock)
)

cumulative_return.plot(
    figsize=(12, 5)
)

plt.title(
    "Samsung Electronics Cumulative Return"
)

plt.show()

# %%
# 하나의 금융분석 Tool로 통합
# analyze_stock()이라는 종합 주식분석 함수를 만들고, 
# 종목코드와 시작일을 받아 주가 데이터를 가져온 다음 종가(Close)를 따로 추출하는 부분입
# analyze_stock() 함수 정의
# get_stock_price() : 앞에서 정의한 함수 호출

# %%
def analyze_stock(
    ticker,
    start="2025-01-01"
):
    
    df = get_stock_price(
        ticker,
        start
    )
    
    close = df["Close"]
    
    returns = (
        close
        .pct_change()
        .dropna()
    )
    
    # 총 수익률
    total_return = (
        close.iloc[-1]
        / close.iloc[0]
        - 1
    )
    
    # 연환산 변동성
    volatility = (
        returns.std()
        * np.sqrt(252)
    )
    
    # MDD
    wealth = (
        1 + returns
    ).cumprod()
    
    peak = wealth.cummax()
    
    drawdown = (
        wealth / peak
        - 1
    )
    
    mdd = drawdown.min()
    
    return {
        "ticker": ticker,
        
        "total_return":
            float(total_return.iloc[0]),
        
        "volatility":
            float(volatility.iloc[0]),
        
        "mdd":
            float(mdd.iloc[0])
    }

# %%
# 앞에서 만들어 놓은 analyze_stock() 함수를 삼성전자에 적용하고, 분석 결과를 result에 저장한 뒤 화면에 출력하는 코드

# %%
result = analyze_stock(
    "005930.KS"
)

result
# Out:
# {'ticker': '005930.KS',
#  'total_return': 3.8457893508981202,
#  'volatility': 0.6141655476149432,
#  'mdd': -0.4283357502200055}

# %%
samsung = analyze_stock(
    "005930.KS"
)

skhynix = analyze_stock(
    "000660.KS"
)

print("삼성전자")
print(samsung)

print()

print("SK하이닉스")
print(skhynix)
# Out:
# 삼성전자
# {'ticker': '005930.KS', 'total_return': 3.8457893508981202, 'volatility': 0.614165537713073, 'mdd': -0.4283357502200056}
#
# SK하이닉스
# {'ticker': '000660.KS', 'total_return': 9.322365973533225, 'volatility': 0.7738449499575731, 'mdd': -0.5471051921241235}

# %% [markdown]
# # 3회차 — 재무제표 및 재무비율 분석¶

# %% [markdown]
# - DataFrame으로 재무제표를 다루게 합니다.

# %%
# 1. 환경

# %%
#!pip install -U openai

# %%
# Python에서 OpenAI API를 사용하고, API 키 같은 환경변수를 다루기 위해 필요한 라이브러리를 불러오는 코드
# import os : Python에 기본으로 들어 있는 운영체제 관련 기능을 제공하는 os 모듈을 가져옵니다.
# OpenAI API를 사용할 때는 특히 환경변수(Environment Variable)에 저장된 API 키를 읽는 데 자주 사용합니다.

# %%
from openai import OpenAI
import os

# %%
# OpenAI API Key를 직접 입력하고, 그 키를 이용해 OpenAI API에 접속할 client 객체를 만드는 코드

# 1. OpenAI API Key 발급
# https://platform.openai.com/api-keys?utm_source=chatgpt.com
# 먼저 OpenAI API Platform에 로그인한 뒤 API Keys 페이지로 이동합니다.
# OpenAI API Keys 페이지
# 프로젝트를 선택하고 Create new secret key를 눌러 새 키를 생성합니다. 프로젝트 API 키는 권한을 All, Restricted, Read Only 등으로 설정할 수도 있습니다.
# 키가 만들어지면 비밀키가 표시됩니다. 중요한 점은 전체 Secret Key는 생성할 때만 확인할 수 있으므로 그때 안전한 곳에 저장해야 한다는 것입니다. 잃어버렸다면 기존 키를 다시 보는 것이 아니라 새 키를 생성해야 합니다.
# 그리고 ChatGPT 구독과 API 사용은 별개입니다

#2. 비빌 장치
# Windows 환경변수에 API Key를 비밀 저장하고 Jupyter에서 불러오는 것입니다.
# ① OpenAI API Key를 준비
# OpenAI에서 발급받은 API Key를 복사합니다.
#     ② Windows 검색에서 환경 변수 검색
# Jupyter를 잠시 닫고 Windows에서 다음 순서로 이동합니다.
# Windows 검색창 → 환경 변수 입력 → 시스템 환경 변수 편집 선택
# 그러면 시스템 속성 창이 열립니다.
# 여기서고급 → 환경 변수를 클릭합니다.
# ③ 사용자 변수에서 새로 만들기
# 환경 변수 창에는 보통 두 영역이 있습니다.

# ┌─────────────────────────────┐
# │ 사용자 변수                  │
# │                             │
# │       [새로 만들기]           │
# ├─────────────────────────────┤
# │ 시스템 변수                  │
# │                             │
# └─────────────────────────────┘

# 위쪽의 사용자 변수에서 새로 만들기를 클릭합니다.
# 시스템 변수에 넣을 필요는 없습니다.
# ④ API Key를 저장
# 다음과 같이 입력합니다.
# 변수 이름:OPENAI_API_KEY
# 변수 값:발급받은 실제 API Key
# 즉,

# ┌──────────────────────────────────┐
# │ 새 사용자 변수                    │
# │                                  │
# │ 변수 이름: OPENAI_API_KEY        │
# │                                  │
# │ 변수 값:   [실제 API Key]         │
# │                                  │
# │              [확인]               │
# └──────────────────────────────────┘

# 입력한 후 확인 → 확인 → 확인을 눌러 창을 닫습니다.
# 이제 API Key가 Python 코드가 아니라 Windows 환경변수에 저장되어 있습니다.
# ⑤ Jupyter Notebook을 새로 실행
# API Key를 환경변수에 저장하기 전에 실행되어 있던 Jupyter Notebook은 종료하고 다시 실행하는 것이 좋습니다.
# 즉,환경변수 저장 → Jupyter 종료 → Jupyter 재실행
# 순서입니다.
# ⑥ Jupyter에서 os로 API Key 가져오기
# Jupyter Notebook의 새 코드 셀에 다음을 입력합니다.
# import os
# OPENAI_API_KEY = os.getenv(
#     "OPENAI_API_KEY"
# )
# 여기서
# os.getenv("OPENAI_API_KEY")# 의 의미는 Windows 환경변수에서 OPENAI_API_KEY라는 이름의 값을 가져와라.입니다.

# 제대로 가져왔는지 확인
# if OPENAI_API_KEY:
#     print("API Key를 정상적으로 불러왔습니다.")
# else:
#     print("API Key를 찾지 못했습니다.")
# 정상이라면:API Key를 정상적으로 불러왔습니다.

# %% [markdown]
# - 아래 코드 주석처리 해제하여 실습

# %%
# from openai import OpenAI

# OPENAI_API_KEY = "여기에_API_KEY"

# client = OpenAI(
#     api_key=OPENAI_API_KEY
# )

# %%
# getpass()는 비밀을 저장하는 기능은 아닙니다. 단지 입력할 때 화면에 보이지 않게 하는 기능

# %%
import pandas as pd
from openai import OpenAI
from getpass import getpass

# %%
# OpenAI Client

# api_key = getpass(
#     "OpenAI API Key: "
# )


# client = OpenAI(
#     api_key=api_key
# )

# %%
financial_data = pd.DataFrame({
    "year": [2023, 2024, 2025],
    "revenue": [100, 115, 130],
    "operating_profit": [10, 14, 18],
    "net_income": [7, 10, 13],
    "assets": [150, 165, 180],
    "equity": [90, 100, 110],
    "liabilities": [60, 65, 70]
})

financial_data
# Out:
#    year  revenue  operating_profit  net_income  assets  equity  liabilities
# 0  2023      100                10           7     150      90           60
# 1  2024      115                14          10     165     100           65
# 2  2025      130                18          13     180     110           70

# %%
# 성장률

# %%
financial_data["revenue_growth"] = (
    financial_data["revenue"]
    .pct_change()
)

# %%
# 영업이익률

# %%
financial_data["operating_margin"] = (
    financial_data["operating_profit"]
    / financial_data["revenue"]
)

# %%
financial_data["ROE"] = (
    financial_data["net_income"]
    / financial_data["equity"]
)

# %%
financial_data["debt_ratio"] = (
    financial_data["liabilities"]
    / financial_data["equity"]
)

# %%
financial_data
# Out:
#    year  revenue  operating_profit  net_income  assets  equity  liabilities  \
# 0  2023      100                10           7     150      90           60
# 1  2024      115                14          10     165     100           65
# 2  2025      130                18          13     180     110           70
#
#    revenue_growth  operating_margin       ROE  debt_ratio
# 0             NaN          0.100000  0.077778    0.666667
# 1        0.150000          0.121739  0.100000    0.650000
# 2        0.130435          0.138462  0.118182    0.636364

# %%
financial_data = pd.DataFrame({
    "year": [2023, 2024, 2025],
    "revenue": [100, 115, 130],
    "operating_profit": [10, 14, 18],
    "net_income": [7, 10, 13],
    "assets": [150, 165, 180],
    "equity": [90, 100, 110],
    "liabilities": [60, 65, 70]
})

financial_data
# Out:
#    year  revenue  operating_profit  net_income  assets  equity  liabilities
# 0  2023      100                10           7     150      90           60
# 1  2024      115                14          10     165     100           65
# 2  2025      130                18          13     180     110           70

# %%
def calculate_financial_ratios(data):

    df = data.copy()

    df["revenue_growth"] = (
        df["revenue"].pct_change()
    )

    df["operating_margin"] = (
        df["operating_profit"]
        / df["revenue"]
    )

    df["ROA"] = (
        df["net_income"]
        / df["assets"]
    )

    df["ROE"] = (
        df["net_income"]
        / df["equity"]
    )

    df["debt_ratio"] = (
        df["liabilities"]
        / df["equity"]
    )

    return df

# %%
result = calculate_financial_ratios(
    financial_data
)

result
# Out:
#    year  revenue  operating_profit  net_income  assets  equity  liabilities  \
# 0  2023      100                10           7     150      90           60
# 1  2024      115                14          10     165     100           65
# 2  2025      130                18          13     180     110           70
#
#    revenue_growth  operating_margin       ROA       ROE  debt_ratio
# 0             NaN          0.100000  0.046667  0.077778    0.666667
# 1        0.150000          0.121739  0.060606  0.100000    0.650000
# 2        0.130435          0.138462  0.072222  0.118182    0.636364

# %%
# LLM에게 재무분석을 시킵니다

# %%
# prompt = f"""
# 당신은 기업 재무분석을 담당하는 금융 애널리스트입니다.

# 다음은 기업의 최근 재무 데이터입니다.

# {result.to_string(index=False)}

# 다음 항목을 분석하세요.

# 1. 매출 성장성
# 2. 영업이익률 변화
# 3. ROA 변화
# 4. ROE 변화
# 5. 부채비율 변화
# 6. 기업의 강점
# 7. 잠재적인 위험요인
# 8. 종합 의견

# 중요:
# - 숫자를 새로 만들어내지 마세요.
# - 제공된 데이터만 사용하세요.
# - Python에서 계산된 재무비율을 해석하세요.
# """

# response = client.responses.create(
#     model="gpt-5.6",
#     input=prompt
# )

# print(response.output_text)

# %%
# 원시 재무데이터
#       ↓
#    Pandas
#       ↓
# 재무비율 계산
#       ↓
#    Python
#       ↓
# 계산된 Financial Metrics
#       ↓
#      LLM
#       ↓
# 금융 애널리스트식 해석

# %%
# 즉 LLM에게 ROE나 영업이익률을 계산시키지 않습니다.

# Python이 계산하고 LLM은 그 결과를 해석하게 하는 것입니다.

# %% [markdown]
# - 4회차: Python 함수 → Tool Calling
# - 5회차: 여러 Tool → Agent Loop
# - 6회차: 뉴스 → Research Agent
# - 7회차: Valuation + Risk
# - 8회차: 역할별 Multi-Agent
# - 9회차: Critic + Revision
# - 10회차: End-to-End Equity Research Agent

# %% [markdown]
# # 4회차 — Tool Calling 기초

# %%
# !pip install -U openai yfinance pandas numpy

# %%
# import 및 API Key

# %%
import json
import numpy as np
import pandas as pd
import yfinance as yf

from openai import OpenAI
from getpass import getpass

# %%
# api_key = getpass("OpenAI API Key: ")

# client = OpenAI(
#     api_key=api_key
# )

# MODEL = "gpt-5"

# %%
# 주가분석 함수 정의

# %%
def get_stock_price(
    ticker,
    period="1y"
):
    df = yf.download(
        ticker,
        period=period,
        auto_adjust=True,
        progress=False
    )

    if df.empty:
        raise ValueError(
            f"{ticker} 데이터를 가져오지 못했습니다."
        )

    return df

# %%
def analyze_stock(
    ticker,
    period="1y"
):

    df = get_stock_price(
        ticker,
        period
    )

    close = df["Close"].squeeze()

    returns = (
        close
        .pct_change()
        .dropna()
    )

    total_return = (
        close.iloc[-1]
        / close.iloc[0]
        - 1
    )

    volatility = (
        returns.std()
        * np.sqrt(252)
    )

    wealth = (
        1 + returns
    ).cumprod()

    drawdown = (
        wealth
        / wealth.cummax()
        - 1
    )

    mdd = drawdown.min()

    return {
        "ticker": ticker,
        "period": period,
        "total_return": round(
            float(total_return), 4
        ),
        "volatility": round(
            float(volatility), 4
        ),
        "mdd": round(
            float(mdd), 4
        )
    }

# %%
# 먼저 Python 함수가 정상인지 확인

# %%
analyze_stock(
    "005930.KS"
)
# Out:
# {'ticker': '005930.KS',
#  'period': '1y',
#  'total_return': 2.8819,
#  'volatility': 0.7401,
#  'mdd': -0.4283}

# %%
# 4. Tool 정의

# %%
tools = [
    {
        "type": "function",
        "name": "analyze_stock",
        "description": (
            "주식 종목의 총수익률, "
            "연환산 변동성, MDD를 분석한다."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "ticker": {
                    "type": "string",
                    "description": (
                        "Yahoo Finance ticker. "
                        "예: 삼성전자 005930.KS"
                    )
                },
                "period": {
                    "type": "string",
                    "description": (
                        "분석 기간. "
                        "예: 6mo, 1y, 2y"
                    )
                }
            },
            "required": [
                "ticker"
            ],
            "additionalProperties": False
        }
    }
]

# %%
# LLM에게 Tool 선택 요청

# %%
# response = client.responses.create(
#     model=MODEL,
#     input="""
#     삼성전자의 최근 1년 주가 성과와
#     위험을 분석해 주세요.
#     """,
#     tools=tools
# )

# for item in response.output:
#     print(item.type)

# %%
# 6. Tool 호출 처리

# %%
# function_calls = [
#     item
#     for item in response.output
#     if item.type == "function_call"
# ]

# function_calls

# %%
# tool_outputs = []

# for call in function_calls:

#     arguments = json.loads(
#         call.arguments
#     )

#     if call.name == "analyze_stock":

#         result = analyze_stock(
#             ticker=arguments["ticker"],
#             period=arguments.get(
#                 "period",
#                 "1y"
#             )
#         )

#         tool_outputs.append({
#             "type":
#                 "function_call_output",

#             "call_id":
#                 call.call_id,

#             "output":
#                 json.dumps(
#                     result,
#                     ensure_ascii=False
#                 )
#         })

# %%
# 7. Tool 결과를 다시 LLM에게 전달

# %%
# final_response = client.responses.create(
#     model=MODEL,
#     previous_response_id=response.id,
#     input=tool_outputs,
#     tools=tools
# )

# print(
#     final_response.output_text
# )

# %% [markdown]
# - 4회차 핵심
# - 사용자 질문
#    ↓
# - LLM
#    ↓
# - Tool 필요 판단
#    ↓
# - analyze_stock()
#    ↓
# - Python 계산
#    ↓
# - LLM 금융 해석

# %% [markdown]
# # 5회차 — Financial Analyst Agent

# %%
# 이번에는 Tool을 여러 개 줍니다.

# 1. 환경 설정

# %%
import json
import numpy as np
import pandas as pd
import yfinance as yf

from openai import OpenAI
from getpass import getpass

# %%
# client = OpenAI(
#     api_key=getpass(
#         "OpenAI API Key: "
#     )
# )

# MODEL = "gpt-5"

# %%
# 2. Market Tool

# %%
def analyze_stock(
    ticker,
    period="1y"
):

    df = yf.download(
        ticker,
        period=period,
        auto_adjust=True,
        progress=False
    )

    if df.empty:
        raise ValueError(
            "주가 데이터가 없습니다."
        )

    close = df["Close"].squeeze()

    returns = (
        close
        .pct_change()
        .dropna()
    )

    total_return = (
        close.iloc[-1]
        / close.iloc[0]
        - 1
    )

    volatility = (
        returns.std()
        * np.sqrt(252)
    )

    wealth = (
        1 + returns
    ).cumprod()

    mdd = (
        wealth
        / wealth.cummax()
        - 1
    ).min()

    return {
        "ticker": ticker,
        "total_return":
            round(float(total_return), 4),
        "volatility":
            round(float(volatility), 4),
        "mdd":
            round(float(mdd), 4)
    }

# %%
# 3. 기업 정보 Tool

# %%
def get_company_profile(
    company
):

    profiles = {
        "삼성전자": {
            "ticker": "005930.KS",
            "sector": "Technology",
            "business": (
                "반도체, 모바일, "
                "가전 등"
            )
        },

        "SK하이닉스": {
            "ticker": "000660.KS",
            "sector": "Technology",
            "business": (
                "메모리 반도체"
            )
        }
    }

    return profiles.get(
        company,
        {
            "error":
                "등록되지 않은 기업입니다."
        }
    )

# %%
get_company_profile(
    "삼성전자"
)
# Out:
# {'ticker': '005930.KS', 'sector': 'Technology', 'business': '반도체, 모바일, 가전 등'}

# %%
# 4. Tools 등록

# %%
tools = [
    {
        "type": "function",
        "name": "get_company_profile",
        "description":
            "기업의 기본 정보를 조회한다.",
        "parameters": {
            "type": "object",
            "properties": {
                "company": {
                    "type": "string"
                }
            },
            "required": [
                "company"
            ],
            "additionalProperties": False
        }
    },

    {
        "type": "function",
        "name": "analyze_stock",
        "description":
            "종목의 시장성과와 위험을 분석한다.",
        "parameters": {
            "type": "object",
            "properties": {
                "ticker": {
                    "type": "string"
                },
                "period": {
                    "type": "string"
                }
            },
            "required": [
                "ticker"
            ],
            "additionalProperties": False
        }
    }
]

# %%
# 5. Agent 실행 함수

# %%
def run_financial_agent(
    question
):

    response = client.responses.create(
        model=MODEL,
        instructions="""
        당신은 Financial Analyst Agent입니다.

        원칙:
        1. 필요한 Tool을 사용하세요.
        2. 숫자를 임의로 만들지 마세요.
        3. 계산은 Tool 결과를 사용하세요.
        4. 수익성과 위험을 구분해서 설명하세요.
        5. 투자판단의 근거를 명확하게 제시하세요.
        """,
        input=question,
        tools=tools
    )

    while True:

        calls = [
            item
            for item in response.output
            if item.type == "function_call"
        ]

        if not calls:
            return response.output_text

        outputs = []

        for call in calls:

            args = json.loads(
                call.arguments
            )

            if call.name == \
                    "get_company_profile":

                result = (
                    get_company_profile(
                        args["company"]
                    )
                )

            elif call.name == \
                    "analyze_stock":

                result = analyze_stock(
                    args["ticker"],
                    args.get(
                        "period",
                        "1y"
                    )
                )

            else:
                result = {
                    "error":
                        "Unknown Tool"
                }

            outputs.append({
                "type":
                    "function_call_output",
                "call_id":
                    call.call_id,
                "output":
                    json.dumps(
                        result,
                        ensure_ascii=False
                    )
            })

        response = client.responses.create(
            model=MODEL,
            previous_response_id=
                response.id,
            input=outputs,
            tools=tools
        )

# %%
# result = run_financial_agent(
#     """
#     삼성전자의 최근 1년 시장성과를
#     분석하고 주요 위험을 설명해주세요.
#     """
# )

# print(result)

# %% [markdown]
# # 6회차 — Financial Research Agent

# %%
# 6회차는 실제 웹 API를 바로 붙이기보다 제공된 뉴스 데이터를 분석하는 방식으로 시작하면 안정적입니다.

# %%
# 1. 환경

# %%
# !pip install -U openai pandas

# %%
# import pandas as pd

# from openai import OpenAI
# from getpass import getpass

# %%
# client = OpenAI(
#     api_key=getpass(
#         "OpenAI API Key: "
#     )
# )

# MODEL = "gpt-5"

# %%
# 2. 뉴스 데이터

# %%
news_data = [
    {
        "date": "2026-07-01",
        "title":
            "AI 서버 투자 확대",
        "source":
            "Example News"
    },
    {
        "date": "2026-07-05",
        "title":
            "메모리 가격 상승 전망",
        "source":
            "Example News"
    },
    {
        "date": "2026-07-10",
        "title":
            "글로벌 경기 둔화 우려",
        "source":
            "Example News"
    }
]

# %%
news_df = pd.DataFrame(
    news_data
)

news_df
# Out:
#          date         title        source
# 0  2026-07-01   AI 서버 투자 확대  Example News
# 1  2026-07-05  메모리 가격 상승 전망  Example News
# 2  2026-07-10  글로벌 경기 둔화 우려  Example News

# %%
# 3. Research Agent

# %%
def research_agent(
    news_df
):

    prompt = f"""
    당신은 Financial Research Analyst입니다.

    아래 뉴스만 이용해서 분석하세요.

    {news_df.to_string(index=False)}

    다음 기준으로 분석하세요.

    1. Positive Catalyst
    2. Negative Risk
    3. Neutral Information
    4. 투자자가 추가 확인해야 할 사항

    반드시 각 판단에
    날짜와 출처를 표시하세요.

    제공되지 않은 사실을
    만들어내지 마세요.
    """

    response = client.responses.create(
        model=MODEL,
        input=prompt
    )

    return response.output_text

# %%
# research_report = (
#     research_agent(
#         news_df
#     )
# )

# print(
#     research_report
# )

# %% [markdown]
# # 7회차 — Valuation & Risk Agent

# %%
#!pip install -U openai pandas numpy

# %%
import pandas as pd
import numpy as np

from openai import OpenAI
from getpass import getpass

# %%
# client = OpenAI(
#     api_key=getpass(
#         "OpenAI API Key: "
#     )
# )

# MODEL = "gpt-5"

# %%
# 2. Peer Valuation 데이터

# %%
valuation_df = pd.DataFrame({
    "company": [
        "A전자",
        "B전자",
        "C전자"
    ],

    "PER": [
        12,
        18,
        15
    ],

    "PBR": [
        1.2,
        2.0,
        1.5
    ],

    "ROE": [
        0.11,
        0.16,
        0.13
    ],

    "growth": [
        0.08,
        0.15,
        0.10
    ]
})

valuation_df
# Out:
#   company  PER  PBR   ROE  growth
# 0     A전자   12  1.2  0.11    0.08
# 1     B전자   18  2.0  0.16    0.15
# 2     C전자   15  1.5  0.13    0.10

# %%
# 3. 산업평균 계산

# %%
industry_average = (
    valuation_df[
        [
            "PER",
            "PBR",
            "ROE",
            "growth"
        ]
    ]
    .mean()
)

industry_average
# Out:
# PER       15.000000
# PBR        1.566667
# ROE        0.133333
# growth     0.110000
# dtype: float64

# %%
# 4. Valuation Score

# %%
def calculate_valuation_score(
    row,
    industry_avg
):

    score = 0

    if row["PER"] < \
            industry_avg["PER"]:
        score += 1

    if row["PBR"] < \
            industry_avg["PBR"]:
        score += 1

    if row["ROE"] > \
            industry_avg["ROE"]:
        score += 1

    if row["growth"] > \
            industry_avg["growth"]:
        score += 1

    return score

# %%
valuation_df["score"] = (
    valuation_df.apply(
        lambda row:
            calculate_valuation_score(
                row,
                industry_average
            ),
        axis=1
    )
)

valuation_df
# Out:
#   company  PER  PBR   ROE  growth  score
# 0     A전자   12  1.2  0.11    0.08      2
# 1     B전자   18  2.0  0.16    0.15      2
# 2     C전자   15  1.5  0.13    0.10      1

# %%
# 5. Risk Score

# %%
def calculate_risk_score(
    volatility,
    mdd,
    debt_ratio
):

    score = 0

    if volatility > 0.30:
        score += 1

    if mdd < -0.30:
        score += 1

    if debt_ratio > 1.0:
        score += 1

    return score

# %%
risk_score = (
    calculate_risk_score(
        volatility=0.35,
        mdd=-0.32,
        debt_ratio=0.8
    )
)

print(
    risk_score
)
# Out:
# 2

# %%
# 6. LLM 분석

# %%
# target = (
#     valuation_df
#     .iloc[0]
#     .to_dict()
# )

# prompt = f"""
# 당신은 Valuation & Risk Analyst입니다.

# 기업 데이터:
# {target}

# Risk Score:
# {risk_score} / 3

# 산업 평균:
# {industry_average.to_dict()}

# 다음을 분석하세요.

# 1. 상대적인 Valuation 수준
# 2. 수익성과 성장성
# 3. 위험 수준
# 4. 투자 매력
# 5. 추가 확인이 필요한 사항

# 점수가 높다는 이유만으로
# 매수를 추천하지 마세요.
# """

# response = client.responses.create(
#     model=MODEL,
#     input=prompt
# )

# print(
#     response.output_text
# )

# %% [markdown]
# # 8회차 — Multi-Agent

# %%
# 이번 회차에서는 각 Agent를 Python class로 분리합니다.

# %%
# 1. 환경

# %%
import numpy as np
import pandas as pd
import yfinance as yf

from openai import OpenAI
from getpass import getpass

# %%
# client = OpenAI(
#     api_key=getpass(
#         "OpenAI API Key: "
#     )
# )

# MODEL = "gpt-5"

# %%
# 2. 실습 데이터

# %%
financial_data = pd.DataFrame({
    "year": [2023, 2024, 2025],
    "revenue": [100, 115, 130],
    "operating_profit": [10, 14, 18],
    "net_income": [7, 10, 13],
    "assets": [150, 165, 180],
    "equity": [90, 100, 110],
    "liabilities": [60, 65, 70]
})

# %%
news_df = pd.DataFrame([
    {
        "date": "2026-07-01",
        "title":
            "AI 서버 투자 확대",
        "source":
            "Example News"
    },
    {
        "date": "2026-07-10",
        "title":
            "경기 둔화 우려",
        "source":
            "Example News"
    }
])

# %%
# 3. Market Analyst

# %%
class MarketAnalyst:

    def analyze(
        self,
        ticker
    ):

        df = yf.download(
            ticker,
            period="1y",
            auto_adjust=True,
            progress=False
        )

        if df.empty:
            return {
                "error":
                    "주가 데이터 없음"
            }

        close = (
            df["Close"]
            .squeeze()
        )

        returns = (
            close
            .pct_change()
            .dropna()
        )

        total_return = (
            close.iloc[-1]
            / close.iloc[0]
            - 1
        )

        volatility = (
            returns.std()
            * np.sqrt(252)
        )

        wealth = (
            1 + returns
        ).cumprod()

        mdd = (
            wealth
            / wealth.cummax()
            - 1
        ).min()

        return {
            "total_return":
                round(
                    float(total_return),
                    4
                ),
            "volatility":
                round(
                    float(volatility),
                    4
                ),
            "mdd":
                round(
                    float(mdd),
                    4
                )
        }

# %%
# 4. Fundamental Analyst

# %%
class FundamentalAnalyst:

    def analyze(
        self,
        df
    ):

        result = df.copy()

        result["revenue_growth"] = (
            result["revenue"]
            .pct_change()
        )

        result["operating_margin"] = (
            result["operating_profit"]
            / result["revenue"]
        )

        result["ROE"] = (
            result["net_income"]
            / result["equity"]
        )

        result["debt_ratio"] = (
            result["liabilities"]
            / result["equity"]
        )

        return (
            result
            .round(4)
            .to_dict(
                orient="records"
            )
        )

# %%
# 5. Research Analyst

# %%
class ResearchAnalyst:

    def analyze(
        self,
        news_df
    ):

        prompt = f"""
        아래 금융뉴스를 분석하세요.

        {news_df.to_string(index=False)}

        Positive Catalyst와
        Negative Risk로 구분하세요.

        날짜와 출처를 유지하세요.
        """

        response = (
            client.responses.create(
                model=MODEL,
                input=prompt
            )
        )

        return (
            response.output_text
        )

# %%
# 6. Risk Analyst

# %%
class RiskAnalyst:

    def analyze(
        self,
        market_result,
        debt_ratio
    ):

        score = 0
        reasons = []

        if market_result[
            "volatility"
        ] > 0.30:

            score += 1

            reasons.append(
                "높은 변동성"
            )

        if market_result[
            "mdd"
        ] < -0.30:

            score += 1

            reasons.append(
                "큰 최대낙폭"
            )

        if debt_ratio > 1.0:

            score += 1

            reasons.append(
                "높은 부채비율"
            )

        return {
            "risk_score":
                score,
            "risk_reasons":
                reasons
        }

# %%
# 7. Portfolio Manager

# %%
class PortfolioManager:

    def synthesize(
        self,
        market,
        fundamental,
        research,
        risk
    ):

        prompt = f"""
        당신은 Portfolio Manager입니다.

        Market:
        {market}

        Fundamental:
        {fundamental}

        Research:
        {research}

        Risk:
        {risk}

        다음 형식으로 종합하세요.

        1. 시장성과
        2. 펀더멘털
        3. 주요 Catalyst
        4. Risk
        5. 종합 의견

        주어진 정보 이외의 숫자를
        생성하지 마세요.
        """

        response = (
            client.responses.create(
                model=MODEL,
                input=prompt
            )
        )

        return (
            response.output_text
        )

# %%
# 8. 실행

# %%
market_agent = (
    MarketAnalyst()
)

fundamental_agent = (
    FundamentalAnalyst()
)

research_agent = (
    ResearchAnalyst()
)

risk_agent = (
    RiskAnalyst()
)

manager = (
    PortfolioManager()
)

# %%
# market_result = (
#     market_agent.analyze(
#         "005930.KS"
#     )
# )

# fundamental_result = (
#     fundamental_agent.analyze(
#         financial_data
#     )
# )

# research_result = (
#     research_agent.analyze(
#         news_df
#     )
# )

# latest_debt_ratio = (
#     financial_data.iloc[-1][
#         "liabilities"
#     ]
#     /
#     financial_data.iloc[-1][
#         "equity"
#     ]
# )

# risk_result = (
#     risk_agent.analyze(
#         market_result,
#         latest_debt_ratio
#     )
# )

# %%
# report = (
#     manager.synthesize(
#         market_result,
#         fundamental_result,
#         research_result,
#         risk_result
#     )
# )

# print(report)

# %% [markdown]
# # 9회차 — Critic Agent

# %%
# 1. 설정

# %%
from openai import OpenAI
from getpass import getpass

# %%
# client = OpenAI(
#     api_key=getpass(
#         "OpenAI API Key: "
#     )
# )

# MODEL = "gpt-5"

# %%
# 2. 검증용 가짜 보고서

# %%
draft_report = """
A전자는 매우 우수한 투자대상이다.

최근 매출은 크게 증가했고
ROE는 25% 이상이다.

향후 주가는 반드시 상승할 것으로 예상된다.

반도체 산업도 지속적으로
성장할 것이다.
"""

# %%
# 3. Critic Agent

# %%
def critic_agent(
    report
):

    prompt = f"""
    당신은 금융분석 검증 담당자입니다.

    아래 보고서를 검증하세요.

    {report}

    다음을 확인하세요.

    1. 출처 없는 숫자
    2. 근거 없는 주장
    3. 과도한 확신
    4. 데이터 기준일 부재
    5. 계산 검증 필요 항목
    6. 추가 자료가 필요한 주장

    표 형식으로 정리하세요.

    각 항목을
    PASS / WARNING / FAIL
    중 하나로 평가하세요.
    """

    response = client.responses.create(
        model=MODEL,
        input=prompt
    )

    return response.output_text

# %%
# critique = critic_agent(
#     draft_report
# )

# print(critique)

# %%
# 4. Revision Agent

# %%
def revision_agent(
    report,
    critique
):

    prompt = f"""
    다음 금융분석 보고서를 수정하세요.

    원본:
    {report}

    Critic Feedback:
    {critique}

    수정 원칙:

    1. 확인되지 않은 숫자를 제거한다.
    2. 근거 없는 투자확신을 제거한다.
    3. 사실과 해석을 구분한다.
    4. 확인이 필요한 부분은
       '추가 확인 필요'라고 표시한다.
    """

    response = client.responses.create(
        model=MODEL,
        input=prompt
    )

    return response.output_text

# %%
# final_report = (
#     revision_agent(
#         draft_report,
#         critique
#     )
# )

# print(final_report)

# %% [markdown]
# # 10회차 — 최종 AI Equity Research Agent

# %%
# 1. 설치 및 환경

# %%
#!pip install -U openai yfinance pandas numpy

# %%
import numpy as np
import pandas as pd
import yfinance as yf

from openai import OpenAI
from getpass import getpass

# %%
# client = OpenAI(
#     api_key=getpass(
#         "OpenAI API Key: "
#     )
# )

# MODEL = "gpt-5"

# %%
# 2. 최종 Agent

# %%
class EquityResearchAgent:

    def __init__(
        self,
        client,
        model
    ):

        self.client = client
        self.model = model

# %%
# Market Analysis

# %%
    def analyze_market(
        self,
        ticker
    ):

        df = yf.download(
            ticker,
            period="1y",
            auto_adjust=True,
            progress=False
        )

        if df.empty:
            return {
                "error":
                    "시장 데이터 없음"
            }

        close = (
            df["Close"]
            .squeeze()
        )

        returns = (
            close
            .pct_change()
            .dropna()
        )

        total_return = (
            close.iloc[-1]
            / close.iloc[0]
            - 1
        )

        volatility = (
            returns.std()
            * np.sqrt(252)
        )

        wealth = (
            1 + returns
        ).cumprod()

        mdd = (
            wealth
            / wealth.cummax()
            - 1
        ).min()

        return {
            "total_return":
                round(
                    float(total_return),
                    4
                ),
            "volatility":
                round(
                    float(volatility),
                    4
                ),
            "mdd":
                round(
                    float(mdd),
                    4
                )
        }

# %%
class EquityResearchAgent:

    def __init__(
        self,
        client,
        model
    ):
        self.client = client
        self.model = model

    def analyze_market(
        self,
        ticker
    ):

        df = yf.download(
            ticker,
            period="1y",
            auto_adjust=True,
            progress=False
        )

        if df.empty:
            return {
                "error":
                    "시장 데이터 없음"
            }

        close = df[
            "Close"
        ].squeeze()

        returns = (
            close
            .pct_change()
            .dropna()
        )

        total_return = (
            close.iloc[-1]
            / close.iloc[0]
            - 1
        )

        volatility = (
            returns.std()
            * np.sqrt(252)
        )

        wealth = (
            1 + returns
        ).cumprod()

        mdd = (
            wealth
            / wealth.cummax()
            - 1
        ).min()

        return {
            "total_return":
                round(
                    float(total_return),
                    4
                ),
            "volatility":
                round(
                    float(volatility),
                    4
                ),
            "mdd":
                round(
                    float(mdd),
                    4
                )
        }

    def analyze_fundamental(
        self,
        df
    ):

        result = df.copy()

        result[
            "revenue_growth"
        ] = (
            result["revenue"]
            .pct_change()
        )

        result[
            "operating_margin"
        ] = (
            result[
                "operating_profit"
            ]
            /
            result["revenue"]
        )

        result["ROE"] = (
            result["net_income"]
            /
            result["equity"]
        )

        result[
            "debt_ratio"
        ] = (
            result["liabilities"]
            /
            result["equity"]
        )

        return (
            result
            .round(4)
            .to_dict(
                orient="records"
            )
        )

    def analyze_research(
        self,
        news_df
    ):

        prompt = f"""
        아래 뉴스만 분석하세요.

        {news_df.to_string(index=False)}

        Positive Catalyst와
        Negative Risk를 분류하세요.

        날짜와 출처를 유지하세요.
        """

        response = (
            self.client.responses.create(
                model=self.model,
                input=prompt
            )
        )

        return (
            response.output_text
        )

    def create_report(
        self,
        company,
        market,
        fundamental,
        research
    ):

        prompt = f"""
        당신은 Equity Research Analyst입니다.

        기업:
        {company}

        Market:
        {market}

        Fundamental:
        {fundamental}

        Research:
        {research}

        다음 형식의 보고서를 작성하세요.

        1. Executive Summary
        2. Market Performance
        3. Financial Performance
        4. Growth & Profitability
        5. Catalysts
        6. Risk Factors
        7. Investment Thesis
        8. 추가 확인 필요 사항

        제공되지 않은 숫자는
        생성하지 마세요.
        """

        response = (
            self.client.responses.create(
                model=self.model,
                input=prompt
            )
        )

        return (
            response.output_text
        )

    def critique(
        self,
        report
    ):

        prompt = f"""
        다음 금융보고서를 검증하세요.

        {report}

        다음 오류를 찾아주세요.

        - 출처 없는 숫자
        - 근거 없는 주장
        - 과도한 투자확신
        - 데이터 기준일 문제
        - 분석과 데이터의 불일치
        """

        response = (
            self.client.responses.create(
                model=self.model,
                input=prompt
            )
        )

        return (
            response.output_text
        )

    def run(
        self,
        company,
        ticker,
        financial_df,
        news_df
    ):

        market = (
            self.analyze_market(
                ticker
            )
        )

        fundamental = (
            self.analyze_fundamental(
                financial_df
            )
        )

        research = (
            self.analyze_research(
                news_df
            )
        )

        report = (
            self.create_report(
                company,
                market,
                fundamental,
                research
            )
        )

        critique = (
            self.critique(
                report
            )
        )

        return {
            "market":
                market,

            "fundamental":
                fundamental,

            "research":
                research,

            "report":
                report,

            "critique":
                critique
        }

# %%
# 3. 실습 데이터

# %%
financial_data = pd.DataFrame({
    "year": [
        2023,
        2024,
        2025
    ],
    "revenue": [
        100,
        115,
        130
    ],
    "operating_profit": [
        10,
        14,
        18
    ],
    "net_income": [
        7,
        10,
        13
    ],
    "assets": [
        150,
        165,
        180
    ],
    "equity": [
        90,
        100,
        110
    ],
    "liabilities": [
        60,
        65,
        70
    ]
})

# %%
news_df = pd.DataFrame([
    {
        "date":
            "2026-07-01",
        "title":
            "AI 서버 투자 확대",
        "source":
            "Example News"
    },
    {
        "date":
            "2026-07-10",
        "title":
            "글로벌 경기 둔화 우려",
        "source":
            "Example News"
    }
])

# %%
# 4. Agent 생성

# %%
# agent = EquityResearchAgent(
#     client=client,
#     model=MODEL
# )

# %%
# 5. 최종 실행

# %%
# result = agent.run(
#     company="삼성전자",
#     ticker="005930.KS",
#     financial_df=
#         financial_data,
#     news_df=
#         news_df
# )

# %%
# 시장분석:

# %%
# result[
#     "market"
# ]

# %%
# 재무분석:

# %%
# result[
#     "fundamental"
# ]

# %%
# Research Agent:

# %%
# print(
#     result[
#         "research"
#     ]
# )

# %%
# 최종 보고서:

# %%
# print(
#     result[
#         "report"
#     ]
# )

# %%
# Critic 결과:

# %%
# print(
#     result[
#         "critique"
#     ]
# )
